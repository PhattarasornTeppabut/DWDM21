# %% [markdown]
# <a href="https://colab.research.google.com/github/PhattarasornTeppabut/DWDM21/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  #ทำงานกับข้อมูลลักษณะตาราง

# %%
from google.colab import drive #เชื่อมเข้ากับ Drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls #คำสั่ง ls ดูว่าเชื่อมในไดร์ฟหรือยัง
# Out:
# drive/  sample_data/

# %%
import os # os เอาไว้จัดการไฟล์และ path #

# %% [markdown]
# # ข้อมูลชุดที่ 1

# %%
path = '/content/drive/My Drive/DWDM2021_DATA_Project' #path คือที่อยู่ของไฟล์
data1  = pd.read_csv(os.path.join(path,'ghg-emission-of-thailand-edited-july-2021.csv'))
data1
# Out:
#      พ.ศ.  ... ปริมาณการปล่อย (GgCO2eq)
# 0    2543  ...                65,326.45
# 1    2543  ...                32,443.00
# 2    2543  ...                47,859.23
# 3    2543  ...                12,557.54
# 4    2543  ...                   769.43
# ..    ...  ...                      ...
# 505  2559  ...                     2.41
# 506  2559  ...                 8,139.72
# 507  2559  ...                    77.72
# 508  2559  ...                   244.21
# 509  2559  ...                 8,310.24
#
# [510 rows x 6 columns]

# %% [markdown]
# # ข้อมูลชุดที่ 2

# %%
path = '/content/drive/My Drive/DWDM2021_DATA_Project' #path คือที่อยู่ของไฟล์
data2  = pd.read_csv(os.path.join(path,'ghg-reduction-of-thailand-may-2021.csv'))
data2
# Out:
#                                                  พ.ศ.  ... Unnamed: 7
# 0                                                2556  ...        NaN
# 1                                                2556  ...        NaN
# 2                                                2556  ...        NaN
# 3                                                2556  ...        NaN
# 4                                                2556  ...        NaN
# 5                                                2557  ...        NaN
# 6                                                2557  ...        NaN
# 7                                                2557  ...        NaN
# 8                                                2557  ...        NaN
# 9                                                2557  ...        NaN
# 10                                               2557  ...        NaN
# 11                                               2557  ...        NaN
# ...

# %% [markdown]
# #ข้อมูลชุดที่ 3

# %%
path = '/content/drive/My Drive/DWDM2021_DATA_Project' #path คือที่อยู่ของไฟล์
data3  = pd.read_csv(os.path.join(path,'highwaystraffic2563.csv'))
data3
# Out:
#      ปริมาณจราจรปี 2563  ...      Unnamed: 19
# 0            ทางหลวงสาย  ...          จังหวัด
# 1                     1  ...    กรุงเทพมหานคร
# 2                     1  ...         ปทุมธานี
# 3                     1  ...  พระนครศรีอยุธยา
# 4                     1  ...  พระนครศรีอยุธยา
# ...                 ...  ...              ...
# 2697               4348  ...             ตรัง
# 2698               4349  ...     สุราษฎร์ธานี
# 2699               4350  ...     สุราษฎร์ธานี
# 2700               4353  ...           ภูเก็ต
# 2701               4363  ...             ยะลา
#
# [2702 rows x 20 columns]

# %% [markdown]
# ## ความเชื่อมโยงของ 3 ตาราง (Index)

# %%
data1.shape #เช็คขนาดของข้อมูลว่ามร
# Out:
# (510, 6)

# %%
data2.shape
# Out:
# (48, 8)

# %%
data2_new = data2.iloc[:,:5]
data2_new
# Out:
#                                                  พ.ศ.  ... สัดส่วนเทียบกรณีฐาน \nณ ปี พ.ศ. 2563 (ร้อยละ)
# 0                                                2556  ...                                         0.270
# 1                                                2556  ...                                         2.190
# 2                                                2556  ...                                         0.770
# 3                                                2556  ...                                         0.560
# 4                                                2556  ...                                         0.110
# 5                                                2557  ...                                         1.100
# 6                                                2557  ...                                         2.360
# 7                                                2557  ...                                         0.003
# ...

# %% [markdown]
# 1. รวม 2 ตารางเข้าด้วยกัน
# 2. เลือกมาเฉพาะบาง column จากอีกตารางหนึ่งมาเเปะไว้
#
#
# รวม 2 ตาราง (.merge())

# %%
data2_new.shape
# Out:
# (48, 5)

# %%
data1_new = data1.iloc[:,[0,1,2,3,5]]
data1_new
# Out:
#      พ.ศ.  ... ปริมาณการปล่อย (GgCO2eq)
# 0    2543  ...                65,326.45
# 1    2543  ...                32,443.00
# 2    2543  ...                47,859.23
# 3    2543  ...                12,557.54
# 4    2543  ...                   769.43
# ..    ...  ...                      ...
# 505  2559  ...                     2.41
# 506  2559  ...                 8,139.72
# 507  2559  ...                    77.72
# 508  2559  ...                   244.21
# 509  2559  ...                 8,310.24
#
# [510 rows x 5 columns]

# %%
merged_table = data2_new.merge(data1_new,how='left',left_on='พ.ศ.',right_on='ภาคการปล่อยก๊าซเรือนกระจก') 
merged_table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-c0f683cdf022> in <module>()
# ----> 1 merged_table = data2_new.merge(data1_new,how='left',left_on='พ.ศ.',right_on='ภาคการปล่อยก๊าซเรือนกระจก')
#       2 merged_table
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7961             copy=copy,
#    7962             indicator=indicator,
# -> 7963             validate=validate,
#    7964         )
#    7965
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
# ...
